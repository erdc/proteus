# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
import numpy as np

# %%
f2p5 = np.genfromtxt("rotation_c0p1cg_vbdf_2_level_3_epsFact0_2.5_phicor0lagrange_history.txt",dtype=float,delimiter=",",names=True)
f5 = np.genfromtxt("rotation_c0p1cg_vbdf_2_level_3_epsFact0_5.0_phicor0lagrange_history.txt",dtype=float,delimiter=",",names=True)
f10 = np.genfromtxt("rotation_c0p1cg_vbdf_2_level_3_epsFact0_10.0_phicor0lagrange_history.txt",dtype=float,delimiter=",",names=True)
f20 = np.genfromtxt("rotation_c0p1cg_vbdf_2_level_3_epsFact0_20.0_phicor0lagrange_history.txt",dtype=float,delimiter=",",names=True)
f40 = np.genfromtxt("rotation_c0p1cg_vbdf_2_level_3_epsFact0_40.0_phicor0lagrange_history.txt",dtype=float,delimiter=",",names=True)
f80 = np.genfromtxt("rotation_c0p1cg_vbdf_2_level_3_epsFact0_80.0_phicor0lagrange_history.txt",dtype=float,delimiter=",",names=True)
f160 = np.genfromtxt("rotation_c0p1cg_vbdf_2_level_3_epsFact0_160.0_phicor0lagrange_history.txt",dtype=float,delimiter=",",names=True)
f320 = np.genfromtxt("rotation_c0p1cg_vbdf_2_level_3_epsFact0_320.0_phicor0lagrange_history.txt",dtype=float,delimiter=",",names=True)

# %%
plt.figure()
plt.plot(f2p5['L2norm_u'])
plt.plot(f5['L2norm_u'])
plt.plot(f10['L2norm_u'])
plt.plot(f20['L2norm_u'])
plt.plot(f40['L2norm_u'])
plt.plot(f80['L2norm_u'])
plt.plot(f160['L2norm_u'])
plt.plot(f320['L2norm_u'])
plt.legend(['2.5','5','10','20','40','80','160','320'])
plt.title("$||u||_{L_2(\Omega)}$")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(f2p5['H1norm_u'])
plt.plot(f5['H1norm_u'])
plt.plot(f10['H1norm_u'])
plt.plot(f20['H1norm_u'])
plt.plot(f40['H1norm_u'])
plt.plot(f80['H1norm_u'])
plt.plot(f160['H1norm_u'])
plt.plot(f320['H1norm_u'])
plt.legend(['2.5','5','10','20','40','80','160','320'])
plt.title("$||u||_{H^1(\Omega)}$")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(f2p5['linfnorm_u'])
plt.plot(f5['linfnorm_u'])
plt.plot(f10['linfnorm_u'])
plt.plot(f20['linfnorm_u'])
plt.plot(f40['linfnorm_u'])
plt.plot(f80['linfnorm_u'])
plt.plot(f160['linfnorm_u'])
plt.plot(f320['linfnorm_u'])
plt.legend(['2.5','5','10','20','40','80','160','320'])
plt.title("$||u||_{\infty}$")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(f2p5['l2norm_u_by_n'])
plt.plot(f5['l2norm_u_by_n'])
plt.plot(f10['l2norm_u_by_n'])
plt.plot(f20['l2norm_u_by_n'])
plt.plot(f40['l2norm_u_by_n'])
plt.plot(f80['l2norm_u_by_n'])
plt.plot(f160['l2norm_u_by_n'])
plt.plot(f320['l2norm_u_by_n'])
plt.legend(['2.5','5','10','20','40','80','160','320'])
plt.title("$||u||_2 / n_{dof}$")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.semilogy(f2p5['reg'])
plt.semilogy(f5['reg'])
plt.semilogy(f10['reg'])
plt.semilogy(f20['reg'])
plt.semilogy(f40['reg'])
plt.semilogy(f80['reg'])
plt.semilogy(f160['reg'])
plt.legend(['2.5','5','10','20','40','80','160'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(f2p5['LAGR'])
plt.plot(f5['LAGR'])
plt.plot(f10['LAGR'])
plt.plot(f20['LAGR'])
plt.plot(f40['LAGR'])
plt.plot(f80['LAGR'])
plt.plot(f160['LAGR'])
plt.plot(f320['LAGR'])
plt.legend(['2.5','5','10','20','40','80','160','320'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(f5['J'])
plt.plot(f10['J'])
plt.plot(f20['J'])
plt.plot(f40['J'])
plt.plot(f80['J'])
plt.plot(f160['J'])
plt.plot(f320['J'])
plt.legend(['5','10','20','40','80','160','320'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(f2p5['LAGR_l'])
plt.plot(f5['LAGR_l'])
plt.plot(f10['LAGR_l'])
plt.plot(f20['LAGR_l'])
plt.plot(f40['LAGR_l'])
plt.plot(f80['LAGR_l'])
plt.plot(f160['LAGR_l'])
plt.plot(f320['LAGR_l'])
plt.legend(['2.5','5','10','20','40','80','160','320'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(f2p5['LAGR_a'])
plt.plot(f5['LAGR_a'])
plt.plot(f10['LAGR_a'])
plt.plot(f20['LAGR_a'])
plt.plot(f40['LAGR_a'])
plt.plot(f80['LAGR_a'])
plt.plot(f160['LAGR_a'])
plt.plot(f320['LAGR_a'])
plt.legend(['2.5','5','10','20','40','80','160','320'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(f2p5['a'])
plt.plot(f5['a'])
plt.plot(f10['a'])
plt.plot(f20['a'])
plt.plot(f40['a'])
plt.plot(f80['a'])
plt.plot(f160['a'])
plt.plot(f320['a'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from tables import  open_file
import matplotlib.tri as mtri
from xml.etree.ElementTree import *
import rotation2D,ls_rotation_2d_so
domain = rotation2D.domain
case_files=["rotation_c0p1cg_vbdf_2_level_3_epsFact0_{}".format(eps) for 
           eps in ['2.5','5.0','10.0','20.0']]#,'40.0']]#,'80.0']]#,'160.0']]#,'320.0']]
plt.figure()
plt.xlabel(r'x')
plt.ylabel(r'y')
plt.xlim(domain.x[0]-0.1*domain.L[0],domain.x[0]+domain.L[0]+0.1*domain.L[0])    
plt.axis('equal')

for case_file in case_files:
    archive = open_file(case_file+'.h5','r')
    nodes = archive.get_node("/nodesSpatial_Domain0")
    x=nodes[:,0]
    y=nodes[:,1]
    elements = archive.get_node("/elementsSpatial_Domain0")
    triang = mtri.Triangulation(x, y, elements)
    xg = np.linspace(0, domain.L[0], 20)
    yg = np.linspace(0, domain.L[1], 20)
    xi, yi = np.meshgrid(xg,yg)
    it = len(ls_rotation_2d_so.tnList)-1
    t = ls_rotation_2d_so.tnList[it]
    if (True):
#    for it,t in enumerate(ls_rotation_2d_so.tnList[:]):
        phi = archive.get_node("/phid_t"+`it`)
        vof = archive.get_node("/vof_t"+`it`)
        colors = ['b','g','r','c','m','y','k','w']
        plt.tricontour(x,y,elements,phi,[0], linewidth=4)
        plt.triplot(x,y,elements)
    archive.close()
# Out:
# <img src="data:image/png;base64,..." width="640">
