# %%
import numpy as np
fp = np.loadtxt("forceHistory_p.txt")
fv = np.loadtxt("forceHistory_v.txt")

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(fp[:,0])
plt.plot(fv[:,0])
plt.plot(fp[:,0]+fv[:,0])
plt.legend(['form drag', 'skin friction', 'total drag'])

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(fp[:,1])
plt.plot(fv[:,1])
plt.plot(fp[:,1]+fv[:,1])
