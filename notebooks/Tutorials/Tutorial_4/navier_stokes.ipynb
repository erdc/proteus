# %% [markdown]
# ### Introduction - Navier-Stokes driven cavity problem with PETSc in Proteus.
#
#
# This notebook illustrates how to setup, solve and visualize a steady-state Navier-Stokes driven-cavity problem in Proteus using solver tools from the PETSc linear algebra library.
#
#
# The driven-cavity problem is a standard benchmark for modeling Stokes and Navier-Stokes equations.  The simulation models a self-contained (e.g. no inflow or outflow) tank of fluid with an external force generating a velocity along the top of the tank.  For example, one could imagine a fan blowing over the top of an open fish tank full of water, causing the water along the surface to have an initial velocity. One (there are many others) nice reference for information about NSE and the driven-cavity problem is "Finite Elements and Faster Iterative Solvers" by Elman, Silvester and Wathen.
#
#
# The governing equations for our problem are the well-known Navier-Stokes equations which we present in non-dimensional form.  Let $p: \Omega \rightarrow \mathbf{R}$, $\mathbf{v}:\Omega \rightarrow \mathbf{R} \times \mathbf{R}$ denote the unknown pressure and velocity of the system.  Note that to distingush between the $x$ and $y$ components of the velocity we use the notation $\mathbf{v} = (u,v)$. The Navier-Stokes equation relate these quantities through
# $$
# \nabla \cdot \mathbf{v}  = 0
# $$
# $$
# - \dfrac{1}{Re} \nabla \cdot (\nabla \mathbf{v}) + \mathbf{v} \cdot \nabla \mathbf{v} + \nabla p = \mathbf{f}.
# $$
# $Re$ is known as the Reynolds number.  As $Re$ increases, the non-linear convection term becomes more dominate to the system's behavior while as $Re$ decreases the the diffusion term will become more important to the system's behavior.  In many real world problems, $Re$ assumes a very large value, which results in convection dominated systems that are very challenging to solve numerically.
#
# In this example, we are interested in solving this system with $Re$ on the order of 1000.  We will discuss more about this later in the tutorial.
#
# Our domain of interest is a square 2D tank
# $$
# \Omega = [-1,1]^{2}
# $$
#  with the Dirichlet boundary conditons
# $$
# u = 1 \text{ and } v = 0 \text{ when } y = 1
# $$
# and
# $$
# \mathbf{v} = 0 \text{ elsewhere on the boundary.}
# $$

# %% [markdown]
# ### Initialze Proteus Library
#
# This first block of code loads and initialzes the libraries required to run the simulation.  numpy and petsc4py are non-proteus libraries that will allow us to use external python libraries for our linear algebra.  The proteus.iproteus command loads the interacitve proteus library.
#
# The profiling commands enable output allowing us to track the progress of our simulation.  Increasing the log level will display more output.

# %%
import numpy as np
import petsc4py as petsc4py
from proteus.iproteus import * 

Profiling.logLevel = 3
Profiling.verbose = True

# %% [markdown]
# ### The Navier-Stokes Class
#
# Once the necessary libraries have been loaded, the next step is to create the NavierStokes class.
#
# In the initialization function (\__init\__), all the terms needed to define the Navier Stokes problem are specified.  Next in the evaluate function, we specify the terms required to evaluate the inner products that appear in the problem description.
#
# Within the Proteus library, a large number of problem classes are already defined and for many simulations the user will not to define the particulars of this class.  We present this mainly for illustrative purposes.

# %%
class NavierStokes_1(TransportCoefficients.TC_base):
    """
    Coefficients for the NS problem
    """
    from proteus.ctransportCoefficients import NavierStokes_2D_Evaluate
    import numpy as np
    def __init__(self,rho=1.0,nu=1.0,g=[0.0,0.0],nd=2):
        self.rho = rho
        self.nu  = nu
        self.g   = np.array(g)
        self.nd  = nd
        mass = {}
        advection = {}
        diffusion = {}
        potential = {}
        reaction = {}
        hamiltonian = {}
        if nd==2:
            variableNames = ['p','u','v']
            mass = {1:{1:'linear'},
                    2:{2:'linear'}}
            advection = {0:{1:'linear',
                            2:'linear'},
                         1:{1:'nonlinear',
                            2:'nonlinear'},
                         2:{1:'nonlinear',
                            2:'nonlinear'}}
            diffusion = {0:{0:{0:'constant'}},
                         1:{1:{1:'constant'}},
                         2:{2:{2:'constant'}}}
            potential = {0:{0:'u'},
                         1:{1:'u'},
                         2:{2:'u'}}
            reaction = {1:{1:'constant'},
                        2:{2:'constant'}}
            hamiltonian = {1:{0:'linear'},
                           2:{0:'linear'}}
            TransportCoefficients.TC_base.__init__(self,
                                                   3,        # number of components (2-velocities 1-pressure)
                                                   mass,
                                                   advection,
                                                   diffusion,
                                                   potential,
                                                   reaction,
                                                   hamiltonian,
                                                   variableNames)
            self.vectorComponents = [1,2]
    def evaluate(self,t,c):
        if self.nd==2:
            self.NavierStokes_2D_Evaluate(self.rho,
                                          self.nu,
                                          self.g,
                                          c[('u',0)],
                                          c[('grad(u)',0)],
                                          c[('u',1)],
                                          c[('u',2)],
                                          c[('m',1)],
                                          c[('dm',1,1)],
                                          c[('m',2)],
                                          c[('dm',2,2)],
                                          c[('f',0)],
                                          c[('df',0,1)],
                                          c[('df',0,2)],
                                          c[('f',1)],
                                          c[('df',1,1)],
                                          c[('df',1,2)],
                                          c[('f',2)],
                                          c[('df',2,1)],
                                          c[('df',2,2)],
                                          c[('a',1,1)],
                                          c[('a',2,2)],
                                          c[('r',1)],
                                          c[('r',2)],
                                          c[('H',1)],
                                          c[('dH',1,0)],
                                          c[('H',2)],
                                          c[('dH',2,0)])

# %% [markdown]
# ### Boundary Conditions
#
# Boundary conditions are an important part of any numeric PDE solver.  In the next block of code we define two functions that will help use to specify problems boundary conditions.

# %%
class uTrue:
    def __init__(self):
        pass
    def uOfX(self,x):
        return 1.
    def uOfXT(self,x,t):
        if t==1.0:
            return 1.
        if t==2.0:
            return 10.
        if t==3.0:
            return 100.
        if t==4.0:
            return 200.
        
class vTrue:
    def __init__(self):
        pass
    def vOfX(self,x):
        return 0.
    def vOfXT(self,x,t):
        return self.vOfX(x)

# %% [markdown]
# ### The Proteus Phliosophy
#
# Next we start getting into the particulars of setting up a simulation in Proteus.
#
# Before proceeding, it is worth noting that Proteus aims to seperate the physics and the numerics of a problem as much as possible.  This compartmentalization allows researchers to focus on the particulars of their particular problem.
#
# In order to facilate this seperation, each simulation is seperated into a set of physical and numerical parameters.

# %% [markdown]
# ### Define the Physics
#
# The first step in defining a problem's physics is to initialize our physics to default_p.  default_p is a collection of default values for the varies physics parameters the Proteus solver expects.  Once the physics has been initialized, we can then go about specifying the problem as we'd like.
#
# In the code box below we override the Proteus defaults to build the driven cavity NS problem we are interested in solving.  See the inline comments for further details.

# %%
physics = default_p
physics.name = "nse_driven_cavity"

# this specifies the problem's dimension
physics.nd = 2

# There are several ways to specify a mesh in Proteus.  Perhaps the eaiset is to initialize
# a coordinate for the bottom left corner of the mesh (.x0) and the length of each coordinate
# axis (.L).
# Thus, the commands below creates a mesh with length 1 in the x and y direction with its bottom 
# left corner at the origin.
physics.x0 = [0.0,0.0]
physics.L = [1.0,1.0]

# Here we specify the simulation coefficients will come from a NavierStokes problem.  To illustrate
# its construction, the construction of this class is shown above.  Note that the Proteus library has
# prewritten classes for most common physics problems.
physics.coefficients = NavierStokes_1(rho=1.0,nu=1.0,g=[0.0,0.0],nd=2)

# Next we define functions for our problems boundary conditions.  Note that these functions
# refer to the earlier boundary condition functions and are not memebers of the the physics class.
def getDBCp(x,flag):
    pass

def getDBCu(x,flag):
    if (x[0] == physics.x0[0] or x[0] == (physics.x0[0]+physics.L[0]) or x[1] == physics.x0[1]):
        return lambda x,t: 0.0
    elif (x[1] == (physics.x0[1] + physics.L[1])):
        return lambda x,t: uTrue().uOfXT(x,t)

def getDBCv(x,flag):
    if (x[0] == physics.x0[0] or x[0] == (physics.x0[0]+physics.L[0]) or \
        x[1] == physics.x0[1] or x[1] == (physics.x0[1]+physics.L[1])):
        return lambda x,t: 0.0

def getAdvFluxBCp(x,flag):
    pass
    
def getAdvFluxBCu(x,flag):
    pass

def getAdvFluxBCv(x,flag):
    pass
    
# Here we attach the boundary condition functions written above to Proteus' physics class.  For this
# problem, the boundary conditions are fully specified by the Dirichlet conditions along the boundary.
# The boundary conditions corresponding to the advectiveFlux and pressure are just place holders.
physics.dirichletConditions = {0:getDBCp, 1:getDBCu, 2:getDBCv}
physics.advectiveFluxBoundaryConditions = {0:getAdvFluxBCp,1:getAdvFluxBCu,2:getAdvFluxBCv}

physics.boundaryCreatesNullSpace = True

# %% [markdown]
# ### Define the Numerics
#
# As with the phyiscs, we start defining the numerics by loading the default values.
#
# Following the initialization, there are three categories of information we specify: Mesh, FE Space and Linear Algebra and Solver Options.
#
# Mesh -
#
# While the dimensions and location of the domain are speicified as part of the simulation's physics, aspects of the refinment are speicifed as part of the simulation's numerics.  In this example, we specify that each coordinate axis of the mesh should have 41 nodes.  While other mesh options are avaliable, these will be demonstrated in other tutorials.
#
# FE Space -
#
# Proteus supports several choices of finite elements to solve Stokes and Navier-Stokes problems.  In this example we

# %%
numerics = default_n

# ******* MESH ********
# this specifies the number of mesh nodes in the x and y directions 
numerics.nn = 41

# ******* FE SPACE *********
# these options specify the finite element space used to approximate the solution

numeric_scheme = "THQuads" #Options: TH or C0P1C0P1

if numeric_scheme == "TH":
    numerics.femSpaces = {0:FemTools.C0_AffineLinearOnSimplexWithNodalBasis, #pressure space
                          1:FemTools.C0_AffineQuadraticOnSimplexWithNodalBasis,
                          2:FemTools.C0_AffineQuadraticOnSimplexWithNodalBasis}  #velocity space

elif numeric_scheme == "C0P1C0P1":
    numerics.femSpaces = {0:FemTools.C0_AffineLinearOnSimplexWithNodalBasis,
                          1:FemTools.C0_AffineLinearOnSimplexWithNodalBasis,
                          2:FemTools.C0_AffineLinearOnSimplexWithNodalBasis}
    numerics.subgridError = SubgridError.NavierStokesASGS_velocity_pressure(physics.coefficients,physics.nd,lag=False)

elif numeric_scheme == "THQuads":
    numerics.quad = True
    numerics.femSpaces = {0:FemTools.C0_AffineLinearOnCubeWithNodalBasis,
                          1:FemTools.Q2,
                          2:FemTools.Q2}

if numeric_scheme == "TH" or numeric_scheme == "C0P1C0P1":
    numerics.elementQuadrature = Quadrature.SimplexGaussQuadrature(physics.nd,4)
    numerics.elementBoundaryQuadrature = Quadrature.SimplexGaussQuadrature(physics.nd-1,4)

elif numeric_scheme == "THQuads":
    numerics.elementQuadrature = Quadrature.CubeGaussQuadrature(physics.nd,4)
    numerics.elementBoundaryQuadrature = Quadrature.CubeGaussQuadrature(physics.nd-1,4)
    
# ******** LINEAR ALGEBRA AND SOLVER OPTIONS ********
    
#numerics.numericalFluxType = NumericalFlux.Diffusion_IIPG_exterior
numerics.matrix = LinearAlgebraTools.SparseMatrix

numerics.multilevelNonlinearSolver = NonlinearSolvers.Newton
numerics.levelNonlinearSolver = NonlinearSolvers.Newton
numerics.maxNonlinearIts = 100
#numerics.maxLineSearches = 100

numerics.multilevelLinearSolver = LinearSolvers.NavierStokes3D
numerics.linearSmoother = LinearSolvers.NavierStokes3D
numerics.l_atol_res = 1.0e-8
numerics.tolFac = 1.0e-8
numerics.nl_atol_res = 1.0e-6

solveIteratively = True
iterativeSolver = 'schur'  # options: 'asm', 'schur', 'direct'

if solveIteratively:
    numerics.multilevelLinearSolver = LinearSolvers.KSP_petsc4py
    numerics.levelLinearSolver = LinearSolvers.KSP_petsc4py
    if iterativeSolver == 'asm':
        petsc4py.PETSc.Options().setValue("ksp_type","gmres")
        petsc4py.PETSc.Options().setValue("pc_type","asm")
        petsc4py.PETSc.Options().setValue("sub_pc_type","lu")
    if iterativeSolver == 'schur':
        petsc4py.PETSc.Options().setValue("ksp_type","fgmres")
        petsc4py.PETSc.Options().setValue("pc_type","fieldsplit")
        petsc4py.PETSc.Options().setValue("pc_fieldsplit_type","schur")
        petsc4py.PETSc.Options().setValue("pc_fieldsplit_schur_fact_type","upper") #upper, diagonal, full
        petsc4py.PETSc.Options().setValue("pc_fieldsplit_schur_precondition","selfp")
        petsc4py.PETSc.Options().setValue("fieldsplit_velocity_ksp_type","preonly")
        petsc4py.PETSc.Options().setValue("fieldsplit_velocity_pc_type","asm")
    #numerics.numericalFluxType = NumericalFlux.NavierStokes_Advection_DiagonalUpwind_Diffusion_IIPG_exterior
    numerics.numericalFluxType = NumericalFlux.Diffusion_IIPG_exterior
else:
    numerics.multilevelLinearSolver = LinearSolvers.LU
    numerics.levelLinearSolver = LinearSolvers.LU
    numerics.numericalFluxType = NumericalFlux.Diffusion_IIPG_exterior
#    numerics.numericalFluxType = None

# %% [markdown]
# ### Initialize SO

# %%
so = default_so
so.name = physics.name
so.sList = [default_s]
so.tnList = [0.0,1.0,2.0,3.0]
#so.tnList = [0.0,1.0,2.0,3.0,4.0]

# %% [markdown]
# ### Solve the Problem

# %%
ns = NumericalSolution.NS_base(so,[physics],[numerics],so.sList,opts)
ns.calculateSolution('run1')

# save solution and grid data for plotting purposes
x = ns.modelList[0].levelModelList[-1].mesh.nodeArray[:,0]
y = ns.modelList[0].levelModelList[-1].mesh.nodeArray[:,1]
triangles = ns.modelList[0].levelModelList[-1].mesh.elementNodesArray
p = ns.modelList[0].levelModelList[-1].u[0].dof
u = ns.modelList[0].levelModelList[-1].u[1].dof
v = ns.modelList[0].levelModelList[-1].u[2].dof
# Out:
# [       8] Initializing NumericalSolution for nse_driven_cavity
#  System includes:
# nse_driven_cavity
#
# [       8] Setting Archiver(s)
# [       8] Setting up MultilevelMesh
# [       8] Building one multilevel mesh for all models
# [       8] Generating mesh for nse_driven_cavity
# [       8] Building 41 x 41 rectangular mesh for nse_driven_cavity
# [      10] Number of quadrilaterals  : 1600
# Number of edges : 3280
# Number of nodes : 1681
#
# [      10] Number of quadrilaterals  : 1600
# Number of edges : 3280
# Number of nodes : 1681
#
# [      10] Numerical Solution Sparse diffusion information key (0, 0) = (array([0, 2, 4], dtype=int32), array([0, 1, 0, 1], dtype=int32))
# [      10] Numerical Solution Sparse diffusion information key (1, 1) = (array([0, 2, 4], dtype=int32), array([0, 1, 0, 1], dtype=int32))
# [      10] Numerical Solution Sparse diffusion information key (2, 2) = (array([0, 2, 4], dtype=int32), array([0, 1, 0, 1], dtype=int32))
# [      10] Setting up MultilevelTransport for nse_driven_cavity
# [      10] Building Transport for each mesh
# [      10] Generating Trial Space
# [      10] Generating Test Space
# [      10] Allocating u
# [      10] Allocating phi
# [      11] Setting Boundary Conditions
# [      11] Setting Boundary Conditions-1
# [      11] Setting Boundary Conditions-2
# [      11] Setting Boundary Conditions-2a
# [      11] Setting Boundary Conditions-3
# [      11] Setting Boundary Conditions-4
# [      11] Initializing OneLevelTransport
# [      11] Sparse diffusion information key (0, 0) = (array([0, 2, 4], dtype=int32), array([0, 1, 0, 1], dtype=int32))
# [      11] Sparse diffusion information key (1, 1) = (array([0, 2, 4], dtype=int32), array([0, 1, 0, 1], dtype=int32))
# [      11] Sparse diffusion information key (2, 2) = (array([0, 2, 4], dtype=int32), array([0, 1, 0, 1], dtype=int32))
# [      11] Updating local to global mappings
# [      11] Building time integration object
# [      11] Calculating numerical quadrature formulas
# [      11] Allocating residual and solution vectors
# [      11] Allocating Jacobian
# [      11] Building sparse matrix structure
# [      12] Allocating parallel storage
# [      12] Allocating ghosted parallel vectors on rank 0
# [      12] Allocating un-ghosted parallel vectors on rank 0
# [      12] Allocating matrix on rank 0
# [      12] ParMat_petsc4py comm.rank= 0 blockSize = 1 par_n= 14803 par_N=14803 par_nghost=0 par_jacobian.getSizes()= ((14803, 14803), (14803, 14803))
# [      12] Building Mesh Transfers
# [      12] Setting nse_driven_cavity stepController to proteus.StepControl.SC_base
# [      12] Setting up MultilevelLinearSolver fornse_driven_cavity
# [      12] multilevelLinearSolverChooser type= proteus.LinearSolvers.KSP_petsc4py
# [      12] KSP atol 1.000000e-08 rtol 1.000000e-03
# [      12] NAHeader Preconditioner SimpleNavierStokes
# [      12] Setting up MultilevelNonLinearSolver for nse_driven_cavity
# [      12] Finished setting up models and solvers
# [      12] Setting up SimTools for nse_driven_cavity
# [      12] Using tnList from so = nse_driven_cavity
# [      12] Time sequence[0.0, 1.0, 2.0, 3.0]
# [      12] NAHeader Num Time Steps 3
# [      12] Setting nse_driven_cavity systemStepController to object of type proteus.SplitOperator.Sequential_MinModelStep
# [      12] Finished NumericalSolution initialization
# [      12] Setting initial conditions
# [      12] No initial conditions provided for model nse_driven_cavity
# [      12] Attaching models and running spin-up step if requested
# [      12] Attaching models to model nse_driven_cavity
# [      12] Attaching models to model nse_driven_cavity
# [      12] Archiving initial conditions
# [      12] Gathering Archive Time step
# [      12] Done Gathering Archive Time Step
# [      12] Estimating initial time derivative and initializing time history for model nse_driven_cavity
# [      12] Choosing initial time step for model nse_driven_cavity
# [      12] Initializing time step on model nse_driven_cavity to dt =  1.00000e+00
# [      12] Initializing time history for model step controller
# [      12] Initializing time step on system Default System to dt =  1.00000e+00
# [      12] Initializing step sequence for system Default System to [(1.0, <proteus.Transport.MultilevelTransport instance at 0x7f91c9043cb0>)]
# [      12] Auxiliary variable calculations for model nse_driven_cavity
# [      12] Starting time stepping
# [      12] ==============================================================
# [      12] Solving over interval [ 0.00000e+00, 1.00000e+00]
# [      12] ==============================================================
# [      12] NumericalAnalytics Model nse_driven_cavity
# [      12] Model: nse_driven_cavity
# [      12] NumericalAnalytics Time Step 1.0
# [      12] StepControl base stepExact t_model= 1.0 tOut= 1.0 t_model_last= 0.0 dt_model= 1.0 setting to 1.0
# [      12]   NumericalAnalytics Newton iteration for level 0
# [      12]   NumericalAnalytics NewtonIteration: 0, NewtonNorm:  9.41630e+00
# [      12]    Newton it 0 norm(r) =  9.41630e+00  		 norm(r)/(rtol*norm(r0)+atol) = 8.60594e+06 test=r
# [      12] before ksp.rtol= 0.001 ksp.atol= 1e-08 ksp.converged= False ksp.its= 0 ksp.norm= 0.0
# [      12] NumericalAnalytics KSPOuterResidual:  9.41630e+00
# [      12] NumericalAnalytics KSPOuterResidual(relative):  1.00000e+00
# [      12]         KSP it 0 norm(r) = 9.416298e+00  norm(r)/|b| = 1.000000e+00 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  4.65495e+00
# [      12] NumericalAnalytics KSPOuterResidual(relative):  4.94351e-01
# [      12]         KSP it 1 norm(r) = 4.654953e+00  norm(r)/|b| = 4.943506e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  2.91918e+00
# [      12] NumericalAnalytics KSPOuterResidual(relative):  3.10013e-01
# [      12]         KSP it 2 norm(r) = 2.919176e+00  norm(r)/|b| = 3.100131e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  2.90917e+00
# [      12] NumericalAnalytics KSPOuterResidual(relative):  3.08951e-01
# [      12]         KSP it 3 norm(r) = 2.909172e+00  norm(r)/|b| = 3.089508e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  1.27911e+00
# [      12] NumericalAnalytics KSPOuterResidual(relative):  1.35840e-01
# [      12]         KSP it 4 norm(r) = 1.279111e+00  norm(r)/|b| = 1.358401e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  1.12479e+00
# [      12] NumericalAnalytics KSPOuterResidual(relative):  1.19452e-01
# [      12]         KSP it 5 norm(r) = 1.124792e+00  norm(r)/|b| = 1.194517e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  9.31454e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  9.89193e-02
# [      12]         KSP it 6 norm(r) = 9.314536e-01  norm(r)/|b| = 9.891930e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  6.59889e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  7.00794e-02
# [      12]         KSP it 7 norm(r) = 6.598886e-01  norm(r)/|b| = 7.007941e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  6.25574e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  6.64353e-02
# [      12]         KSP it 8 norm(r) = 6.255742e-01  norm(r)/|b| = 6.643526e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  5.70637e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  6.06010e-02
# [      12]         KSP it 9 norm(r) = 5.706373e-01  norm(r)/|b| = 6.060102e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  4.64674e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  4.93478e-02
# [      12]         KSP it 10 norm(r) = 4.646736e-01  norm(r)/|b| = 4.934780e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  4.40699e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  4.68018e-02
# [      12]         KSP it 11 norm(r) = 4.406993e-01  norm(r)/|b| = 4.680176e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  3.66748e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  3.89482e-02
# [      12]         KSP it 12 norm(r) = 3.667478e-01  norm(r)/|b| = 3.894820e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  3.11420e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  3.30724e-02
# [      12]         KSP it 13 norm(r) = 3.114196e-01  norm(r)/|b| = 3.307240e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  2.97074e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  3.15489e-02
# [      12]         KSP it 14 norm(r) = 2.970739e-01  norm(r)/|b| = 3.154891e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  2.64328e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  2.80714e-02
# [      12]         KSP it 15 norm(r) = 2.643284e-01  norm(r)/|b| = 2.807137e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  2.41352e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  2.56313e-02
# [      12]         KSP it 16 norm(r) = 2.413516e-01  norm(r)/|b| = 2.563127e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  2.26137e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  2.40155e-02
# [      12]         KSP it 17 norm(r) = 2.261367e-01  norm(r)/|b| = 2.401545e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  1.92442e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  2.04371e-02
# [      12]         KSP it 18 norm(r) = 1.924416e-01  norm(r)/|b| = 2.043707e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  1.80354e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  1.91534e-02
# [      12]         KSP it 19 norm(r) = 1.803542e-01  norm(r)/|b| = 1.915341e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  1.71893e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  1.82549e-02
# [      12]         KSP it 20 norm(r) = 1.718934e-01  norm(r)/|b| = 1.825488e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  1.49591e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  1.58864e-02
# [      12]         KSP it 21 norm(r) = 1.495912e-01  norm(r)/|b| = 1.588642e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      12] NumericalAnalytics KSPOuterResidual:  1.40434e-01
# [      12] NumericalAnalytics KSPOuterResidual(relative):  1.49140e-02
# [      12]         KSP it 22 norm(r) = 1.404343e-01  norm(r)/|b| = 1.491396e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  1.29680e-01
# [      13] NumericalAnalytics KSPOuterResidual(relative):  1.37718e-02
# [      13]         KSP it 23 norm(r) = 1.296798e-01  norm(r)/|b| = 1.377184e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  1.17509e-01
# [      13] NumericalAnalytics KSPOuterResidual(relative):  1.24793e-02
# [      13]         KSP it 24 norm(r) = 1.175086e-01  norm(r)/|b| = 1.247928e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  1.11855e-01
# [      13] NumericalAnalytics KSPOuterResidual(relative):  1.18789e-02
# [      13]         KSP it 25 norm(r) = 1.118549e-01  norm(r)/|b| = 1.187886e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  1.02100e-01
# [      13] NumericalAnalytics KSPOuterResidual(relative):  1.08429e-02
# [      13]         KSP it 26 norm(r) = 1.020998e-01  norm(r)/|b| = 1.084288e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  9.19940e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  9.76966e-03
# [      13]         KSP it 27 norm(r) = 9.199403e-02  norm(r)/|b| = 9.769660e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  8.80280e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  9.34847e-03
# [      13]         KSP it 28 norm(r) = 8.802799e-02  norm(r)/|b| = 9.348471e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  8.06628e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  8.56630e-03
# [      13]         KSP it 29 norm(r) = 8.066281e-02  norm(r)/|b| = 8.566298e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  7.39994e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  7.85865e-03
# [      13]         KSP it 30 norm(r) = 7.399935e-02  norm(r)/|b| = 7.858646e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  7.39994e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  7.85865e-03
# [      13]         KSP it 30 norm(r) = 7.399935e-02  norm(r)/|b| = 7.858646e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  7.38818e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  7.84616e-03
# [      13]         KSP it 31 norm(r) = 7.388182e-02  norm(r)/|b| = 7.846164e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  7.17945e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  7.62450e-03
# [      13]         KSP it 32 norm(r) = 7.179453e-02  norm(r)/|b| = 7.624496e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  6.63331e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  7.04450e-03
# [      13]         KSP it 33 norm(r) = 6.633308e-02  norm(r)/|b| = 7.044497e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  6.49075e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  6.89310e-03
# [      13]         KSP it 34 norm(r) = 6.490751e-02  norm(r)/|b| = 6.893103e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  6.10330e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  6.48164e-03
# [      13]         KSP it 35 norm(r) = 6.103302e-02  norm(r)/|b| = 6.481636e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  5.70111e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  6.05451e-03
# [      13]         KSP it 36 norm(r) = 5.701108e-02  norm(r)/|b| = 6.054511e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  5.47728e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  5.81681e-03
# [      13]         KSP it 37 norm(r) = 5.477279e-02  norm(r)/|b| = 5.816807e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  5.06990e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  5.38417e-03
# [      13]         KSP it 38 norm(r) = 5.069896e-02  norm(r)/|b| = 5.384171e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  4.75711e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  5.05200e-03
# [      13]         KSP it 39 norm(r) = 4.757113e-02  norm(r)/|b| = 5.052000e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  4.54307e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  4.82468e-03
# [      13]         KSP it 40 norm(r) = 4.543066e-02  norm(r)/|b| = 4.824683e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  4.15318e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  4.41063e-03
# [      13]         KSP it 41 norm(r) = 4.153177e-02  norm(r)/|b| = 4.410626e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  3.86411e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  4.10364e-03
# [      13]         KSP it 42 norm(r) = 3.864106e-02  norm(r)/|b| = 4.103636e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  3.64812e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  3.87426e-03
# [      13]         KSP it 43 norm(r) = 3.648123e-02  norm(r)/|b| = 3.874265e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  3.33946e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  3.54647e-03
# [      13]         KSP it 44 norm(r) = 3.339464e-02  norm(r)/|b| = 3.546472e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  3.12457e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  3.31826e-03
# [      13]         KSP it 45 norm(r) = 3.124571e-02  norm(r)/|b| = 3.318259e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  2.87906e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  3.05752e-03
# [      13]         KSP it 46 norm(r) = 2.879056e-02  norm(r)/|b| = 3.057525e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  2.54647e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  2.70432e-03
# [      13]         KSP it 47 norm(r) = 2.546466e-02  norm(r)/|b| = 2.704317e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  2.35817e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  2.50435e-03
# [      13]         KSP it 48 norm(r) = 2.358171e-02  norm(r)/|b| = 2.504351e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  2.18053e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  2.31570e-03
# [      13]         KSP it 49 norm(r) = 2.180532e-02  norm(r)/|b| = 2.315700e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  1.99964e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  2.12360e-03
# [      13]         KSP it 50 norm(r) = 1.999644e-02  norm(r)/|b| = 2.123599e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  1.89147e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  2.00872e-03
# [      13]         KSP it 51 norm(r) = 1.891470e-02  norm(r)/|b| = 2.008720e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  1.66805e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  1.77145e-03
# [      13]         KSP it 52 norm(r) = 1.668049e-02  norm(r)/|b| = 1.771449e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  1.50434e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  1.59759e-03
# [      13]         KSP it 53 norm(r) = 1.504338e-02  norm(r)/|b| = 1.597590e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  1.40563e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  1.49276e-03
# [      13]         KSP it 54 norm(r) = 1.405627e-02  norm(r)/|b| = 1.492760e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  1.25863e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  1.33665e-03
# [      13]         KSP it 55 norm(r) = 1.258630e-02  norm(r)/|b| = 1.336650e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  1.16009e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  1.23200e-03
# [      13]         KSP it 56 norm(r) = 1.160086e-02  norm(r)/|b| = 1.231998e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  1.06273e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  1.12861e-03
# [      13]         KSP it 57 norm(r) = 1.062733e-02  norm(r)/|b| = 1.128611e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  9.42559e-03
# [      13] NumericalAnalytics KSPOuterResidual(relative):  1.00099e-03
# [      13]         KSP it 58 norm(r) = 9.425594e-03  norm(r)/|b| = 1.000987e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] NumericalAnalytics KSPOuterResidual:  8.89511e-03
# [      13] NumericalAnalytics KSPOuterResidual(relative):  9.44650e-04
# [      13]         KSP it 59 norm(r) = 8.895109e-03  norm(r)/|b| = 9.446504e-04 ; atol=1.000000e-08 rtol=1.000000e-03
# [      13] after ksp.rtol= 0.001 ksp.atol= 1e-08 ksp.converged= True ksp.its= 59 ksp.norm= 0.00889510927898 reason = 2
# [      13]   NumericalAnalytics NewtonIteration: 1, NewtonNorm:  1.24869e-02
# [      13]    Newton it 1 norm(r) =  1.24869e-02  		 norm(r)/(rtol*norm(r0)+atol) = 11412.3 test=r
# [      13] before ksp.rtol= 0.001 ksp.atol= 1e-08 ksp.converged= False ksp.its= 59 ksp.norm= 0.00889510927898
# [      13] NumericalAnalytics KSPOuterResidual:  1.24869e-02
# [      13] NumericalAnalytics KSPOuterResidual(relative):  1.00000e+00
# [      13]         KSP it 0 norm(r) = 1.248689e-02  norm(r)/|b| = 1.000000e+00 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.20066e-02
# [      14] NumericalAnalytics KSPOuterResidual(relative):  9.61539e-01
# [      14]         KSP it 1 norm(r) = 1.200663e-02  norm(r)/|b| = 9.615394e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  9.84089e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  7.88098e-01
# [      14]         KSP it 2 norm(r) = 9.840885e-03  norm(r)/|b| = 7.880976e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  9.15018e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  7.32783e-01
# [      14]         KSP it 3 norm(r) = 9.150176e-03  norm(r)/|b| = 7.327828e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  8.79422e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  7.04276e-01
# [      14]         KSP it 4 norm(r) = 8.794219e-03  norm(r)/|b| = 7.042764e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  8.30427e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  6.65039e-01
# [      14]         KSP it 5 norm(r) = 8.304268e-03  norm(r)/|b| = 6.650391e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  8.02376e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  6.42575e-01
# [      14]         KSP it 6 norm(r) = 8.023755e-03  norm(r)/|b| = 6.425745e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  7.51925e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  6.02171e-01
# [      14]         KSP it 7 norm(r) = 7.519246e-03  norm(r)/|b| = 6.021714e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  7.04458e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  5.64159e-01
# [      14]         KSP it 8 norm(r) = 7.044583e-03  norm(r)/|b| = 5.641585e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  6.71982e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  5.38150e-01
# [      14]         KSP it 9 norm(r) = 6.719816e-03  norm(r)/|b| = 5.381499e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  6.29461e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  5.04098e-01
# [      14]         KSP it 10 norm(r) = 6.294610e-03  norm(r)/|b| = 5.040977e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  5.95508e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  4.76907e-01
# [      14]         KSP it 11 norm(r) = 5.955082e-03  norm(r)/|b| = 4.769069e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  5.52257e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  4.42270e-01
# [      14]         KSP it 12 norm(r) = 5.522575e-03  norm(r)/|b| = 4.422700e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  5.03182e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  4.02968e-01
# [      14]         KSP it 13 norm(r) = 5.031821e-03  norm(r)/|b| = 4.029684e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  4.73019e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  3.78813e-01
# [      14]         KSP it 14 norm(r) = 4.730192e-03  norm(r)/|b| = 3.788128e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  4.34321e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  3.47822e-01
# [      14]         KSP it 15 norm(r) = 4.343213e-03  norm(r)/|b| = 3.478219e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  3.92419e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  3.14265e-01
# [      14]         KSP it 16 norm(r) = 3.924188e-03  norm(r)/|b| = 3.142647e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  3.58836e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  2.87370e-01
# [      14]         KSP it 17 norm(r) = 3.588358e-03  norm(r)/|b| = 2.873701e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  3.19022e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  2.55485e-01
# [      14]         KSP it 18 norm(r) = 3.190216e-03  norm(r)/|b| = 2.554853e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  2.92032e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  2.33871e-01
# [      14]         KSP it 19 norm(r) = 2.920318e-03  norm(r)/|b| = 2.338708e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  2.70705e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  2.16791e-01
# [      14]         KSP it 20 norm(r) = 2.707049e-03  norm(r)/|b| = 2.167914e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  2.39114e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  1.91492e-01
# [      14]         KSP it 21 norm(r) = 2.391140e-03  norm(r)/|b| = 1.914921e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  2.17083e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  1.73849e-01
# [      14]         KSP it 22 norm(r) = 2.170830e-03  norm(r)/|b| = 1.738488e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  2.02545e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  1.62206e-01
# [      14]         KSP it 23 norm(r) = 2.025451e-03  norm(r)/|b| = 1.622062e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.84127e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  1.47456e-01
# [      14]         KSP it 24 norm(r) = 1.841267e-03  norm(r)/|b| = 1.474560e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.71061e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  1.36993e-01
# [      14]         KSP it 25 norm(r) = 1.710612e-03  norm(r)/|b| = 1.369927e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.60728e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  1.28717e-01
# [      14]         KSP it 26 norm(r) = 1.607281e-03  norm(r)/|b| = 1.287175e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.49670e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  1.19861e-01
# [      14]         KSP it 27 norm(r) = 1.496696e-03  norm(r)/|b| = 1.198614e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.42290e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  1.13952e-01
# [      14]         KSP it 28 norm(r) = 1.422900e-03  norm(r)/|b| = 1.139516e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.34187e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  1.07462e-01
# [      14]         KSP it 29 norm(r) = 1.341870e-03  norm(r)/|b| = 1.074624e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.26233e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  1.01093e-01
# [      14]         KSP it 30 norm(r) = 1.262334e-03  norm(r)/|b| = 1.010928e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.26233e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  1.01093e-01
# [      14]         KSP it 30 norm(r) = 1.262334e-03  norm(r)/|b| = 1.010928e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.22948e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  9.84614e-02
# [      14]         KSP it 31 norm(r) = 1.229477e-03  norm(r)/|b| = 9.846144e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.18581e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  9.49646e-02
# [      14]         KSP it 32 norm(r) = 1.185813e-03  norm(r)/|b| = 9.496464e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.15041e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  9.21291e-02
# [      14]         KSP it 33 norm(r) = 1.150406e-03  norm(r)/|b| = 9.212910e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.11244e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  8.90889e-02
# [      14]         KSP it 34 norm(r) = 1.112443e-03  norm(r)/|b| = 8.908891e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.05200e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  8.42481e-02
# [      14]         KSP it 35 norm(r) = 1.051997e-03  norm(r)/|b| = 8.424814e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  1.00066e-03
# [      14] NumericalAnalytics KSPOuterResidual(relative):  8.01371e-02
# [      14]         KSP it 36 norm(r) = 1.000663e-03  norm(r)/|b| = 8.013713e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  9.40611e-04
# [      14] NumericalAnalytics KSPOuterResidual(relative):  7.53279e-02
# [      14]         KSP it 37 norm(r) = 9.406108e-04  norm(r)/|b| = 7.532789e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  8.77614e-04
# [      14] NumericalAnalytics KSPOuterResidual(relative):  7.02828e-02
# [      14]         KSP it 38 norm(r) = 8.776136e-04  norm(r)/|b| = 7.028282e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  8.20017e-04
# [      14] NumericalAnalytics KSPOuterResidual(relative):  6.56703e-02
# [      14]         KSP it 39 norm(r) = 8.200174e-04  norm(r)/|b| = 6.567029e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  7.54268e-04
# [      14] NumericalAnalytics KSPOuterResidual(relative):  6.04048e-02
# [      14]         KSP it 40 norm(r) = 7.542684e-04  norm(r)/|b| = 6.040484e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      14] NumericalAnalytics KSPOuterResidual:  6.86965e-04
# [      14] NumericalAnalytics KSPOuterResidual(relative):  5.50149e-02
# [      14]         KSP it 41 norm(r) = 6.869654e-04  norm(r)/|b| = 5.501495e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  6.35767e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  5.09148e-02
# [      15]         KSP it 42 norm(r) = 6.357673e-04  norm(r)/|b| = 5.091480e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  5.83659e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  4.67418e-02
# [      15]         KSP it 43 norm(r) = 5.836593e-04  norm(r)/|b| = 4.674178e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  5.24127e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  4.19742e-02
# [      15]         KSP it 44 norm(r) = 5.241267e-04  norm(r)/|b| = 4.197417e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  4.75680e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  3.80944e-02
# [      15]         KSP it 45 norm(r) = 4.756804e-04  norm(r)/|b| = 3.809440e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  4.40481e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  3.52755e-02
# [      15]         KSP it 46 norm(r) = 4.404812e-04  norm(r)/|b| = 3.527550e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  4.03638e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  3.23249e-02
# [      15]         KSP it 47 norm(r) = 4.036375e-04  norm(r)/|b| = 3.232491e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  3.72941e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  2.98666e-02
# [      15]         KSP it 48 norm(r) = 3.729407e-04  norm(r)/|b| = 2.986659e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  3.40992e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  2.73080e-02
# [      15]         KSP it 49 norm(r) = 3.409924e-04  norm(r)/|b| = 2.730804e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  3.14335e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  2.51732e-02
# [      15]         KSP it 50 norm(r) = 3.143348e-04  norm(r)/|b| = 2.517319e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  2.92593e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  2.34320e-02
# [      15]         KSP it 51 norm(r) = 2.925926e-04  norm(r)/|b| = 2.343199e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  2.70429e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  2.16570e-02
# [      15]         KSP it 52 norm(r) = 2.704289e-04  norm(r)/|b| = 2.165703e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  2.49083e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  1.99476e-02
# [      15]         KSP it 53 norm(r) = 2.490831e-04  norm(r)/|b| = 1.994758e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  2.34757e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  1.88003e-02
# [      15]         KSP it 54 norm(r) = 2.347567e-04  norm(r)/|b| = 1.880026e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  2.17994e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  1.74578e-02
# [      15]         KSP it 55 norm(r) = 2.179941e-04  norm(r)/|b| = 1.745784e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  2.01231e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  1.61154e-02
# [      15]         KSP it 56 norm(r) = 2.012310e-04  norm(r)/|b| = 1.611539e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  1.92501e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  1.54162e-02
# [      15]         KSP it 57 norm(r) = 1.925010e-04  norm(r)/|b| = 1.541625e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  1.76590e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  1.41421e-02
# [      15]         KSP it 58 norm(r) = 1.765903e-04  norm(r)/|b| = 1.414206e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  1.60210e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  1.28302e-02
# [      15]         KSP it 59 norm(r) = 1.602098e-04  norm(r)/|b| = 1.283024e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  1.40061e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  1.12166e-02
# [      15]         KSP it 60 norm(r) = 1.400608e-04  norm(r)/|b| = 1.121663e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  1.40061e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  1.12166e-02
# [      15]         KSP it 60 norm(r) = 1.400608e-04  norm(r)/|b| = 1.121663e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  1.30618e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  1.04604e-02
# [      15]         KSP it 61 norm(r) = 1.306181e-04  norm(r)/|b| = 1.046042e-02 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  1.21896e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  9.76193e-03
# [      15]         KSP it 62 norm(r) = 1.218962e-04  norm(r)/|b| = 9.761933e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  1.16365e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  9.31898e-03
# [      15]         KSP it 63 norm(r) = 1.163650e-04  norm(r)/|b| = 9.318979e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  1.11434e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  8.92411e-03
# [      15]         KSP it 64 norm(r) = 1.114344e-04  norm(r)/|b| = 8.924111e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  1.05010e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  8.40960e-03
# [      15]         KSP it 65 norm(r) = 1.050097e-04  norm(r)/|b| = 8.409602e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  1.00386e-04
# [      15] NumericalAnalytics KSPOuterResidual(relative):  8.03932e-03
# [      15]         KSP it 66 norm(r) = 1.003861e-04  norm(r)/|b| = 8.039321e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  9.31932e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  7.46328e-03
# [      15]         KSP it 67 norm(r) = 9.319317e-05  norm(r)/|b| = 7.463283e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  8.78653e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  7.03660e-03
# [      15]         KSP it 68 norm(r) = 8.786528e-05  norm(r)/|b| = 7.036605e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  8.35567e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  6.69156e-03
# [      15]         KSP it 69 norm(r) = 8.355671e-05  norm(r)/|b| = 6.691557e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  7.77919e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  6.22989e-03
# [      15]         KSP it 70 norm(r) = 7.779189e-05  norm(r)/|b| = 6.229887e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  7.11611e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  5.69887e-03
# [      15]         KSP it 71 norm(r) = 7.116111e-05  norm(r)/|b| = 5.698868e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  6.65952e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  5.33321e-03
# [      15]         KSP it 72 norm(r) = 6.659519e-05  norm(r)/|b| = 5.333210e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  6.08666e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  4.87444e-03
# [      15]         KSP it 73 norm(r) = 6.086658e-05  norm(r)/|b| = 4.874440e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  5.61646e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  4.49789e-03
# [      15]         KSP it 74 norm(r) = 5.616461e-05  norm(r)/|b| = 4.497888e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  5.13877e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  4.11533e-03
# [      15]         KSP it 75 norm(r) = 5.138766e-05  norm(r)/|b| = 4.115331e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  4.61446e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  3.69544e-03
# [      15]         KSP it 76 norm(r) = 4.614456e-05  norm(r)/|b| = 3.695442e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  4.25151e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  3.40478e-03
# [      15]         KSP it 77 norm(r) = 4.251510e-05  norm(r)/|b| = 3.404780e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  3.81478e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  3.05503e-03
# [      15]         KSP it 78 norm(r) = 3.814781e-05  norm(r)/|b| = 3.055030e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  3.42690e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  2.74440e-03
# [      15]         KSP it 79 norm(r) = 3.426899e-05  norm(r)/|b| = 2.744398e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  3.17311e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  2.54116e-03
# [      15]         KSP it 80 norm(r) = 3.173112e-05  norm(r)/|b| = 2.541156e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  2.83302e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  2.26880e-03
# [      15]         KSP it 81 norm(r) = 2.833021e-05  norm(r)/|b| = 2.268797e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  2.56998e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  2.05815e-03
# [      15]         KSP it 82 norm(r) = 2.569983e-05  norm(r)/|b| = 2.058146e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      15] NumericalAnalytics KSPOuterResidual:  2.39425e-05
# [      15] NumericalAnalytics KSPOuterResidual(relative):  1.91742e-03
# [      15]         KSP it 83 norm(r) = 2.394254e-05  norm(r)/|b| = 1.917415e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  2.20039e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.76216e-03
# [      16]         KSP it 84 norm(r) = 2.200385e-05  norm(r)/|b| = 1.762157e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  2.05176e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.64313e-03
# [      16]         KSP it 85 norm(r) = 2.051759e-05  norm(r)/|b| = 1.643131e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.93162e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.54692e-03
# [      16]         KSP it 86 norm(r) = 1.931623e-05  norm(r)/|b| = 1.546921e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.83203e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.46716e-03
# [      16]         KSP it 87 norm(r) = 1.832031e-05  norm(r)/|b| = 1.467164e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.76966e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.41721e-03
# [      16]         KSP it 88 norm(r) = 1.769658e-05  norm(r)/|b| = 1.417213e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.72027e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.37766e-03
# [      16]         KSP it 89 norm(r) = 1.720267e-05  norm(r)/|b| = 1.377659e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.63373e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.30836e-03
# [      16]         KSP it 90 norm(r) = 1.633735e-05  norm(r)/|b| = 1.308360e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.63373e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.30836e-03
# [      16]         KSP it 90 norm(r) = 1.633735e-05  norm(r)/|b| = 1.308360e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.61244e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.29130e-03
# [      16]         KSP it 91 norm(r) = 1.612436e-05  norm(r)/|b| = 1.291304e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.56889e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.25643e-03
# [      16]         KSP it 92 norm(r) = 1.568885e-05  norm(r)/|b| = 1.256426e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.50388e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.20437e-03
# [      16]         KSP it 93 norm(r) = 1.503884e-05  norm(r)/|b| = 1.204371e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.46563e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.17374e-03
# [      16]         KSP it 94 norm(r) = 1.465635e-05  norm(r)/|b| = 1.173739e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.38089e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.10588e-03
# [      16]         KSP it 95 norm(r) = 1.380894e-05  norm(r)/|b| = 1.105876e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.30193e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.04263e-03
# [      16]         KSP it 96 norm(r) = 1.301925e-05  norm(r)/|b| = 1.042634e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.22857e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  9.83890e-04
# [      16]         KSP it 97 norm(r) = 1.228573e-05  norm(r)/|b| = 9.838905e-04 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] after ksp.rtol= 0.001 ksp.atol= 1e-08 ksp.converged= True ksp.its= 97 ksp.norm= 1.22857285141e-05 reason = 2
# [      16]   NumericalAnalytics NewtonIteration: 2, NewtonNorm:  1.29044e-05
# [      16]    Newton it 2 norm(r) =  1.29044e-05  		 norm(r)/(rtol*norm(r0)+atol) = 11.7939 test=r
# [      16] before ksp.rtol= 0.001 ksp.atol= 1e-08 ksp.converged= False ksp.its= 97 ksp.norm= 1.22857285141e-05
# [      16] NumericalAnalytics KSPOuterResidual:  1.29044e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  1.00000e+00
# [      16]         KSP it 0 norm(r) = 1.290444e-05  norm(r)/|b| = 1.000000e+00 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.28902e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  9.98895e-01
# [      16]         KSP it 1 norm(r) = 1.289018e-05  norm(r)/|b| = 9.988952e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.16354e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  9.01658e-01
# [      16]         KSP it 2 norm(r) = 1.163539e-05  norm(r)/|b| = 9.016584e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.14055e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  8.83840e-01
# [      16]         KSP it 3 norm(r) = 1.140545e-05  norm(r)/|b| = 8.838397e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.10619e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  8.57216e-01
# [      16]         KSP it 4 norm(r) = 1.106189e-05  norm(r)/|b| = 8.572156e-01 ; atol=1.000000e-08 rtol=1.000000e-03
# [      16] NumericalAnalytics KSPOuterResidual:  1.04981e-05
# [      16] NumericalAnalytics KSPOuterResidual(relative):  8.13524e-01
# ...
# [      46]         KSP it 116 norm(r) = 5.782554e-07  norm(r)/|b| = 9.352224e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  5.47779e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  8.85933e-03
# [      46]         KSP it 117 norm(r) = 5.477793e-07  norm(r)/|b| = 8.859328e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  5.22436e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  8.44945e-03
# [      46]         KSP it 118 norm(r) = 5.224362e-07  norm(r)/|b| = 8.449449e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  5.00600e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  8.09628e-03
# [      46]         KSP it 119 norm(r) = 5.005996e-07  norm(r)/|b| = 8.096283e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  4.65320e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  7.52570e-03
# [      46]         KSP it 120 norm(r) = 4.653200e-07  norm(r)/|b| = 7.525700e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  4.65320e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  7.52570e-03
# [      46]         KSP it 120 norm(r) = 4.653200e-07  norm(r)/|b| = 7.525700e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  4.62116e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  7.47388e-03
# [      46]         KSP it 121 norm(r) = 4.621162e-07  norm(r)/|b| = 7.473884e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  4.50896e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  7.29242e-03
# [      46]         KSP it 122 norm(r) = 4.508962e-07  norm(r)/|b| = 7.292421e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  4.18263e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  6.76463e-03
# [      46]         KSP it 123 norm(r) = 4.182626e-07  norm(r)/|b| = 6.764632e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  4.06585e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  6.57577e-03
# [      46]         KSP it 124 norm(r) = 4.065851e-07  norm(r)/|b| = 6.575770e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  3.94671e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  6.38308e-03
# [      46]         KSP it 125 norm(r) = 3.946710e-07  norm(r)/|b| = 6.383082e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  3.64329e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  5.89236e-03
# [      46]         KSP it 126 norm(r) = 3.643291e-07  norm(r)/|b| = 5.892357e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  3.42074e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  5.53242e-03
# [      46]         KSP it 127 norm(r) = 3.420739e-07  norm(r)/|b| = 5.532419e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  3.33278e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  5.39016e-03
# [      46]         KSP it 128 norm(r) = 3.332779e-07  norm(r)/|b| = 5.390161e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  3.17915e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  5.14169e-03
# [      46]         KSP it 129 norm(r) = 3.179146e-07  norm(r)/|b| = 5.141688e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  3.00019e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  4.85226e-03
# [      46]         KSP it 130 norm(r) = 3.000192e-07  norm(r)/|b| = 4.852261e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  2.91696e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  4.71765e-03
# [      46]         KSP it 131 norm(r) = 2.916962e-07  norm(r)/|b| = 4.717653e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  2.82530e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  4.56941e-03
# [      46]         KSP it 132 norm(r) = 2.825302e-07  norm(r)/|b| = 4.569410e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      46] NumericalAnalytics KSPOuterResidual:  2.67237e-07
# [      46] NumericalAnalytics KSPOuterResidual(relative):  4.32207e-03
# [      46]         KSP it 133 norm(r) = 2.672373e-07  norm(r)/|b| = 4.322075e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  2.59008e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  4.18898e-03
# [      47]         KSP it 134 norm(r) = 2.590079e-07  norm(r)/|b| = 4.188979e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  2.53399e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  4.09826e-03
# [      47]         KSP it 135 norm(r) = 2.533986e-07  norm(r)/|b| = 4.098258e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  2.44159e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  3.94882e-03
# [      47]         KSP it 136 norm(r) = 2.441587e-07  norm(r)/|b| = 3.948820e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  2.34929e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  3.79955e-03
# [      47]         KSP it 137 norm(r) = 2.349292e-07  norm(r)/|b| = 3.799550e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  2.27755e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  3.68352e-03
# [      47]         KSP it 138 norm(r) = 2.277552e-07  norm(r)/|b| = 3.683523e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  2.17288e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  3.51424e-03
# [      47]         KSP it 139 norm(r) = 2.172882e-07  norm(r)/|b| = 3.514240e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  2.06335e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  3.33708e-03
# [      47]         KSP it 140 norm(r) = 2.063346e-07  norm(r)/|b| = 3.337085e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  2.00400e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  3.24110e-03
# [      47]         KSP it 141 norm(r) = 2.004000e-07  norm(r)/|b| = 3.241103e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.93630e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  3.13161e-03
# [      47]         KSP it 142 norm(r) = 1.936300e-07  norm(r)/|b| = 3.131611e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.84360e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.98168e-03
# [      47]         KSP it 143 norm(r) = 1.843599e-07  norm(r)/|b| = 2.981685e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.78028e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.87927e-03
# [      47]         KSP it 144 norm(r) = 1.780276e-07  norm(r)/|b| = 2.879271e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.71934e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.78071e-03
# [      47]         KSP it 145 norm(r) = 1.719335e-07  norm(r)/|b| = 2.780711e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.63936e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.65137e-03
# [      47]         KSP it 146 norm(r) = 1.639361e-07  norm(r)/|b| = 2.651366e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.59282e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.57609e-03
# [      47]         KSP it 147 norm(r) = 1.592820e-07  norm(r)/|b| = 2.576095e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.55448e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.51408e-03
# [      47]         KSP it 148 norm(r) = 1.554476e-07  norm(r)/|b| = 2.514080e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.49081e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.41112e-03
# [      47]         KSP it 149 norm(r) = 1.490815e-07  norm(r)/|b| = 2.411120e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.44003e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.32898e-03
# [      47]         KSP it 150 norm(r) = 1.440025e-07  norm(r)/|b| = 2.328977e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.44003e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.32898e-03
# [      47]         KSP it 150 norm(r) = 1.440025e-07  norm(r)/|b| = 2.328977e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.43573e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.32203e-03
# [      47]         KSP it 151 norm(r) = 1.435729e-07  norm(r)/|b| = 2.322029e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.40274e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.26868e-03
# [      47]         KSP it 152 norm(r) = 1.402742e-07  norm(r)/|b| = 2.268679e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.33468e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.15859e-03
# [      47]         KSP it 153 norm(r) = 1.334675e-07  norm(r)/|b| = 2.158593e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.31070e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.11981e-03
# [      47]         KSP it 154 norm(r) = 1.310697e-07  norm(r)/|b| = 2.119813e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.28810e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  2.08327e-03
# [      47]         KSP it 155 norm(r) = 1.288102e-07  norm(r)/|b| = 2.083269e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.21554e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  1.96591e-03
# [      47]         KSP it 156 norm(r) = 1.215539e-07  norm(r)/|b| = 1.965913e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.17559e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  1.90130e-03
# [      47]         KSP it 157 norm(r) = 1.175588e-07  norm(r)/|b| = 1.901299e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.15579e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  1.86928e-03
# [      47]         KSP it 158 norm(r) = 1.155788e-07  norm(r)/|b| = 1.869276e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.10990e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  1.79506e-03
# [      47]         KSP it 159 norm(r) = 1.109901e-07  norm(r)/|b| = 1.795062e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.05450e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  1.70546e-03
# [      47]         KSP it 160 norm(r) = 1.054498e-07  norm(r)/|b| = 1.705458e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.03366e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  1.67176e-03
# [      47]         KSP it 161 norm(r) = 1.033664e-07  norm(r)/|b| = 1.671763e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  1.00403e-07
# [      47] NumericalAnalytics KSPOuterResidual(relative):  1.62384e-03
# [      47]         KSP it 162 norm(r) = 1.004030e-07  norm(r)/|b| = 1.623836e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  9.56192e-08
# [      47] NumericalAnalytics KSPOuterResidual(relative):  1.54647e-03
# [      47]         KSP it 163 norm(r) = 9.561923e-08  norm(r)/|b| = 1.546466e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      47] NumericalAnalytics KSPOuterResidual:  9.30079e-08
# [      47] NumericalAnalytics KSPOuterResidual(relative):  1.50423e-03
# [      47]         KSP it 164 norm(r) = 9.300787e-08  norm(r)/|b| = 1.504232e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      48] NumericalAnalytics KSPOuterResidual:  9.07401e-08
# [      48] NumericalAnalytics KSPOuterResidual(relative):  1.46755e-03
# [      48]         KSP it 165 norm(r) = 9.074006e-08  norm(r)/|b| = 1.467555e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      48] NumericalAnalytics KSPOuterResidual:  8.64967e-08
# [      48] NumericalAnalytics KSPOuterResidual(relative):  1.39893e-03
# [      48]         KSP it 166 norm(r) = 8.649665e-08  norm(r)/|b| = 1.398925e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      48] NumericalAnalytics KSPOuterResidual:  8.35060e-08
# [      48] NumericalAnalytics KSPOuterResidual(relative):  1.35056e-03
# [      48]         KSP it 167 norm(r) = 8.350603e-08  norm(r)/|b| = 1.350557e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      48] NumericalAnalytics KSPOuterResidual:  8.08668e-08
# [      48] NumericalAnalytics KSPOuterResidual(relative):  1.30787e-03
# [      48]         KSP it 168 norm(r) = 8.086680e-08  norm(r)/|b| = 1.307872e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      48] NumericalAnalytics KSPOuterResidual:  7.68989e-08
# [      48] NumericalAnalytics KSPOuterResidual(relative):  1.24370e-03
# [      48]         KSP it 169 norm(r) = 7.689892e-08  norm(r)/|b| = 1.243699e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      48] NumericalAnalytics KSPOuterResidual:  7.42533e-08
# [      48] NumericalAnalytics KSPOuterResidual(relative):  1.20091e-03
# [      48]         KSP it 170 norm(r) = 7.425332e-08  norm(r)/|b| = 1.200912e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      48] NumericalAnalytics KSPOuterResidual:  7.15101e-08
# [      48] NumericalAnalytics KSPOuterResidual(relative):  1.15654e-03
# [      48]         KSP it 171 norm(r) = 7.151007e-08  norm(r)/|b| = 1.156545e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      48] NumericalAnalytics KSPOuterResidual:  6.80668e-08
# [      48] NumericalAnalytics KSPOuterResidual(relative):  1.10086e-03
# [      48]         KSP it 172 norm(r) = 6.806675e-08  norm(r)/|b| = 1.100855e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      48] NumericalAnalytics KSPOuterResidual:  6.46557e-08
# [      48] NumericalAnalytics KSPOuterResidual(relative):  1.04569e-03
# [      48]         KSP it 173 norm(r) = 6.465567e-08  norm(r)/|b| = 1.045687e-03 ; atol=1.000000e-08 rtol=1.000000e-03
# [      48] NumericalAnalytics KSPOuterResidual:  6.10662e-08
# [      48] NumericalAnalytics KSPOuterResidual(relative):  9.87633e-04
# [      48]         KSP it 174 norm(r) = 6.106615e-08  norm(r)/|b| = 9.876333e-04 ; atol=1.000000e-08 rtol=1.000000e-03
# [      48] after ksp.rtol= 0.001 ksp.atol= 1e-08 ksp.converged= True ksp.its= 174 ksp.norm= 6.10661533174e-08 reason = 2
# [      48]   NumericalAnalytics NewtonIteration: 4, NewtonNorm:  6.10653e-08
# [      48]    Newton it 5 norm(r) =  6.10653e-08  		 norm(r)/(rtol*norm(r0)+atol) =  6.44511e-03
# [      48] Step Taken, Model step t= 3.00000e+00, dt= 1.00000e+00 for model nse_driven_cavity
# [      48] Step Taken, System time step t= 3.00000e+00, dt= 1.00000e+00
# [      48] Potential System time step t= 4.00000e+00, dt= 1.00000e+00 for next step
# [      48] Gathering Archive Time step
# [      48] Done Gathering Archive Time Step
# [      48] Closing solution archive for nse_driven_cavity
# [      48] Closing Archive
# [      48] Done Closing Archive

# %% [markdown]
# ### Visualize the Solution
#
# It is important to visualize and post process your solutions to verify your simulation has generated the correct results.  In the code blocks below plots are generated for the

# %%
# %pylab inline
import matplotlib.pyplot as plt
# build mesh for plotting
xg = np.linspace(0, physics.domain.L[0], 200)
yg = np.linspace(0, physics.domain.L[1], 200)
xi, yi = np.meshgrid(xg,yg)
cartcoord = zip(x,y)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/alistair/proteus/linux2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['log']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
### Run the following blocks for triangular grids (e.g TH, C0P1C0P1)
import matplotlib.tri as mtri 
triang = mtri.Triangulation(x, y, triangles) 
u_interp_lin = mtri.LinearTriInterpolator(triang, u[:x.shape[0]]) 
v_interp_lin = mtri.LinearTriInterpolator(triang, v[:x.shape[0]]) 
u_lin = u_interp_lin(xi, yi) 
v_lin = v_interp_lin(xi, yi)

# %%
# Velocity magnitude profile
plt.tricontourf(x,y,triangles,np.sqrt((u[:x.shape[0]]**2 + v[:x.shape[0]]**2))) 
plt.streamplot(xg, yg, u_lin, v_lin,color='k') 
plt.title('Velocity Streamlines') 
plt.axis('equal') 
plt.xlim((0,physics.domain.L[0]));

# %%
# x-component of velocity profile
plt.tricontourf(x,y,triangles,u[:x.shape[0]])
plt.streamplot(xg, yg, u_lin, v_lin,color='k') 
plt.title('Velocity Streamlines') 
plt.axis('equal') 
plt.xlim((0,physics.domain.L[0]));

# %%
# y-component of velocity profile
plt.tricontourf(x,y,triangles,v[:x.shape[0]])
plt.streamplot(xg, yg, u_lin, v_lin,color='k') 
plt.title('Velocity Streamlines') 
plt.axis('equal') 
plt.xlim((0,physics.domain.L[0]));

# %%
# pressure approximation
import matplotlib.pyplot as plt
plt.clf()
plt.tricontourf(x,y,triangles,p[:x.shape[0]])
plt.xlabel('x'); plt.ylabel('y')
plt.title('NSE Driven Cavity Solution Approximation'); plt.colorbar()
plt.show()

# %%
### Run the following blocks for quadrilateral meshes (e.g THQuads)
import matplotlib.pyplot as plt
import scipy.interpolate

u_interp_lin = scipy.interpolate.LinearNDInterpolator(cartcoord,u[:x.shape[0]] )
v_interp_lin = scipy.interpolate.LinearNDInterpolator(cartcoord,v[:y.shape[0]] )
p_interp_lin = scipy.interpolate.LinearNDInterpolator(cartcoord,p[:p.shape[0]] )
u_lin = u_interp_lin(xi,yi)
v_lin = v_interp_lin(xi,yi)
p_lin = p_interp_lin(xi,yi)

# %%
# Velocity magnitude profile
plt.imshow(np.sqrt((u_lin**2+v_lin**2)),vmin=u[:x.shape[0]].min(), vmax=u[:x.shape[0]].max(), origin='lower',
          extent=[x.min(),x.max(),y.min(),y.max()])
plt.colorbar()
plt.streamplot(xg, yg, u_lin, v_lin,color='k') 
plt.title('Velocity Streamlines') 
plt.axis('equal') 
plt.xlim((0,physics.domain.L[0]));

# %%
# x-component of velocity profile
plt.imshow(u_lin,vmin=u[:x.shape[0]].min(), vmax=u[:x.shape[0]].max(), origin='lower',
          extent=[x.min(),x.max(),y.min(),y.max()])
plt.colorbar()
plt.axis('equal') 
plt.xlim((0,physics.domain.L[0]));

# %%
# y-component of velocity profile
plt.imshow(v_lin,vmin=u[:x.shape[0]].min(), vmax=u[:x.shape[0]].max(), origin='lower',
          extent=[x.min(),x.max(),y.min(),y.max()])
plt.colorbar()
plt.axis('equal') 
plt.xlim((0,physics.domain.L[0]));

# %%
# p-component of velocity profile
plt.imshow(p_lin,vmin=u[:x.shape[0]].min(), vmax=u[:x.shape[0]].max(), origin='lower',
          extent=[x.min(),x.max(),y.min(),y.max()])
plt.colorbar()
plt.axis('equal') 
plt.xlim((0,physics.domain.L[0]));
